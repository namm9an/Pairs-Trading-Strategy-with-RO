# %% [markdown]
# <a href="https://colab.research.google.com/github/namm9an/Pairs-Trading-Strategy-with-RO/blob/main/Pairs_trading_strategy_with_RO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crusade: Pairs Trading with RO
#
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
##Equal Pairs trading

# %%
import numpy as np
import pandas as pd
import datetime
import yfinance as yf
import matplotlib.pyplot as plt
import math
import os
import warnings

import statsmodels.tsa.vector_ar.vecm as vm
import statsmodels.formula.api as sm
from statsmodels.tsa.stattools import adfuller

# %matplotlib inline

# %% [markdown]
# # Set the Sectors

# %%
oil =  'RRRP3.SA CSAN3.SA DMMO3.SA ENAT3.SA RPMG3.SA PETR4.SA BRDT3.SA PRIO3.SA UGPA3.SA'
metal =  'BRAP4.SA CMIN3.SA MMXM3.SA VALE3.SA'
steel =  'FESA4.SA GGBR4.SA GOAU4.SA CSNA3.SA USIM3.SA'
paper =  'RANI3.SA KLBN4.SA MSPA4.SA SUZB3.SA'
transp_material =  'FRAS3.SA POMO4.SA RAPT4.SA RCSL4.SA RSUL4.SA TUPY3.SA MWET4.SA'
machines =  'SHUL4.SA WEGE3.SA EALT4.SA AERI3.SA BDLL4.SA ROMI3.SA INEP4.SA KEPL3.SA FRIO3.SA NORD3.SA'
rail_roads =  'RLOG3.SA VSPT3.SA RAIL3.SA'
highways =  'CCRO3.SA ECOR3.SA TPIS3.SA'
storage =  'PSVM11.SA STBP3.SA'
services =  'ATMP3.SA DTCY3.SA ALPK3.SA PRNR3.SA SEQL3.SA VLID3.SA'
agriculture =  'AGRO3.SA FRTA3.SA SLCE3.SA TESA3.SA'
meat =  'BRFS3.SA BAUH4.SA JBSS3.SA MRFG3.SA BEEF3.SA MNPR3.SA'
food =  'CAML3.SA JOPA4.SA MDIA3.SA ODER4.SA'
construction =  'AVLL3.SA CALI4.SA CRDE3.SA CURY3.SA CYRE3.SA DIRR3.SA EVEN3.SA EZTC3.SA GFSA3.SA HBOR3.SA JHSF3.SA JFEN3.SA LAVV3.SA MELK3.SA MTRE3.SA MDNE3.SA MRVE3.SA PDGR3.SA PLPL3.SA RDNI3.SA RSID3.SA TCSA3.SA TEND3.SA TRIS3.SA VIVR3.SA'
fabric =  'CEDO4.SA CTNM4.SA DOHL4.SA ECPR4.SA CTKA4.SA PTNT4.SA CTSA4.SA SGPS3.SA TEKA4.SA TXRX4.SA'
clothes_shoes =  'HGTX3.SA TFCO4.SA ALPA4.SA CAMB3.SA GRND3.SA VULC3.SA ARZZ3.SA CEAB3.SA CGRA4.SA SOMA3.SA GUAR3.SA LLIS3.SA AMAR3.SA LREN3.SA'
education =  'ANIM3.SA BAHI3.SA COGN3.SA CSED3.SA SEER3.SA YDUQ3.SA'
car_rental =  'RENT3.SA LCAM3.SA MOVI3.SA VAMO3.SA'
retail =  'ALLD3.SA MGLU3.SA VVAR3.SA BTOW3.SA CNTO3.SA ESPA3.SA LAME4.SA PETZ3.SA LJQQ3.SA SLED4.SA'
hospitals =  'AALR3.SA DASA3.SA FLRY3.SA HAPV3.SA PARD3.SA GNDI3.SA MATD3.SA ODPV3.SA QUAL3.SA RDOR3.SA'
drugstores =  'PNVL4.SA DMVF3.SA HYPE3.SA PGMN3.SA PFRM3.SA RADL3.SA'
it =  'BMOB3.SA ENJU3.SA LINX3.SA LWSA3.SA CASH3.SA MBLY3.SA MOSI3.SA NGRD3.SA SQIA3.SA TOTS3.SA WEST3.SA'
telecom =  'OIBR4.SA TELB4.SA VIVT3.SA TIMS3.SA'
electricity =  'AESB3.SA AFLT3.SA ALUP4.SA CBEE3.SA CEBR3.SA CEED4.SA EEEL4.SA CLSC4.SA GPAR3.SA CEPE3.SA CMIG4.SA CESP3.SA CEEB3.SA COCE3.SA CPLE3.SA CSRN3.SA CPFE3.SA EKTR4.SA ELET3.SA LIPR3.SA EMAE4.SA ENBR3.SA ENGI4.SA ENMT4.SA ENEV3.SA EGIE3.SA EQPA3.SA EQTL3.SA POWE3.SA GEPA4.SA LIGT3.SA NEOE3.SA OMGE3.SA REDE3.SA RNEW4.SA TAEE4.SA TRPL4.SA'
water =  'AMBP3.SA CASN4.SA CSMG3.SA ORVR3.SA SBSP3.SA SAPR4.SA'
banking =  'ABCB4.SA RPAD3.SA BRIV4.SA BAZA3.SA BMGB4.SA BIDI4.SA BPAN4.SA BGIP4.SA BEES4.SA BRSR3.SA BBDC4.SA BBAS3.SA BSLI4.SA BPAC3.SA ITSA4.SA ITUB4.SA BMEB4.SA BMIN4.SA BNBR3.SA PINE4.SA SANB4.SA'
securities =  ''
financial_services =  'PDTC3.SA PPLA11.SA B3SA3.SA BOAS3.SA CIEL3.SA CARD3.SA'
insurance =  'BRGE3.SA BBSE3.SA IRBR3.SA PSSA3.SA CSAB4.SA SULA4.SA APER3.SA WIZS3.SA'
real_estate =  'ALSO3.SA BRML3.SA BRPR3.SA CORR4.SA CCPR3.SA GSHP3.SA HBTS5.SA HBRE3.SA IGBR3.SA IGTA3.SA JPSA3.SA LOGG3.SA MULT3.SA SCAR3.SA BBRK3.SA LPSB3.SA'

sectorNames = [ 'oil', 'metal', 'steel', 'paper', 'transp_material', 'machines', 'rail_roads', 'highways', 'storage', 'services', 'agriculture', 'meat', 'food', 'construction', 'fabric', 'clothes_shoes', 'education', 'car_rental', 'retail', 'hospitals', 'drugstores', 'it', 'telecom', 'electricity', 'water', 'banking', 'financial_services', 'insurance', 'real_estate' ]
sectors = [ oil, metal, steel, paper, transp_material, machines, rail_roads, highways, storage, services, agriculture, meat, food, construction, fabric, clothes_shoes, education, car_rental, retail, hospitals, drugstores, it, telecom, electricity, water, banking, financial_services, insurance, real_estate ]

sectorTickers = { s[0]: s[1] for s in zip(sectorNames, sectors)}

print(sectorTickers)
# Out:
# {'oil': 'RRRP3.SA CSAN3.SA DMMO3.SA ENAT3.SA RPMG3.SA PETR4.SA BRDT3.SA PRIO3.SA UGPA3.SA', 'metal': 'BRAP4.SA CMIN3.SA MMXM3.SA VALE3.SA', 'steel': 'FESA4.SA GGBR4.SA GOAU4.SA CSNA3.SA USIM3.SA', 'paper': 'RANI3.SA KLBN4.SA MSPA4.SA SUZB3.SA', 'transp_material': 'FRAS3.SA POMO4.SA RAPT4.SA RCSL4.SA RSUL4.SA TUPY3.SA MWET4.SA', 'machines': 'SHUL4.SA WEGE3.SA EALT4.SA AERI3.SA BDLL4.SA ROMI3.SA INEP4.SA KEPL3.SA FRIO3.SA NORD3.SA', 'rail_roads': 'RLOG3.SA VSPT3.SA RAIL3.SA', 'highways': 'CCRO3.SA ECOR3.SA TPIS3.SA', 'storage': 'PSVM11.SA STBP3.SA', 'services': 'ATMP3.SA DTCY3.SA ALPK3.SA PRNR3.SA SEQL3.SA VLID3.SA', 'agriculture': 'AGRO3.SA FRTA3.SA SLCE3.SA TESA3.SA', 'meat': 'BRFS3.SA BAUH4.SA JBSS3.SA MRFG3.SA BEEF3.SA MNPR3.SA', 'food': 'CAML3.SA JOPA4.SA MDIA3.SA ODER4.SA', 'construction': 'AVLL3.SA CALI4.SA CRDE3.SA CURY3.SA CYRE3.SA DIRR3.SA EVEN3.SA EZTC3.SA GFSA3.SA HBOR3.SA JHSF3.SA JFEN3.SA LAVV3.SA MELK3.SA MTRE3.SA MDNE3.SA MRVE3.SA PDGR3.SA PLPL3.SA RDNI3.SA RSID3.SA TCSA3.SA TEND3.SA TRIS3.SA VIVR3.SA', 'fabric': 'CEDO4.SA CTNM4.SA DOHL4.SA ECPR4.SA CTKA4.SA PTNT4.SA CTSA4.SA SGPS3.SA TEKA4.SA TXRX4.SA', 'clothes_shoes': 'HGTX3.SA TFCO4.SA ALPA4.SA CAMB3.SA GRND3.SA VULC3.SA ARZZ3.SA CEAB3.SA CGRA4.SA SOMA3.SA GUAR3.SA LLIS3.SA AMAR3.SA LREN3.SA', 'education': 'ANIM3.SA BAHI3.SA COGN3.SA CSED3.SA SEER3.SA YDUQ3.SA', 'car_rental': 'RENT3.SA LCAM3.SA MOVI3.SA VAMO3.SA', 'retail': 'ALLD3.SA MGLU3.SA VVAR3.SA BTOW3.SA CNTO3.SA ESPA3.SA LAME4.SA PETZ3.SA LJQQ3.SA SLED4.SA', 'hospitals': 'AALR3.SA DASA3.SA FLRY3.SA HAPV3.SA PARD3.SA GNDI3.SA MATD3.SA ODPV3.SA QUAL3.SA RDOR3.SA', 'drugstores': 'PNVL4.SA DMVF3.SA HYPE3.SA PGMN3.SA PFRM3.SA RADL3.SA', 'it': 'BMOB3.SA ENJU3.SA LINX3.SA LWSA3.SA CASH3.SA MBLY3.SA MOSI3.SA NGRD3.SA SQIA3.SA TOTS3.SA WEST3.SA', 'telecom': 'OIBR4.SA TELB4.SA VIVT3.SA TIMS3.SA', 'electricity': 'AESB3.SA AFLT3.SA ALUP4.SA CBEE3.SA CEBR3.SA CEED4.SA EEEL4.SA CLSC4.SA GPAR3.SA CEPE3.SA CMIG4.SA CESP3.SA CEEB3.SA COCE3.SA CPLE3.SA CSRN3.SA CPFE3.SA EKTR4.SA ELET3.SA LIPR3.SA EMAE4.SA ENBR3.SA ENGI4.SA ENMT4.SA ENEV3.SA EGIE3.SA EQPA3.SA EQTL3.SA POWE3.SA GEPA4.SA LIGT3.SA NEOE3.SA OMGE3.SA REDE3.SA RNEW4.SA TAEE4.SA TRPL4.SA', 'water': 'AMBP3.SA CASN4.SA CSMG3.SA ORVR3.SA SBSP3.SA SAPR4.SA', 'banking': 'ABCB4.SA RPAD3.SA BRIV4.SA BAZA3.SA BMGB4.SA BIDI4.SA BPAN4.SA BGIP4.SA BEES4.SA BRSR3.SA BBDC4.SA BBAS3.SA BSLI4.SA BPAC3.SA ITSA4.SA ITUB4.SA BMEB4.SA BMIN4.SA BNBR3.SA PINE4.SA SANB4.SA', 'financial_services': 'PDTC3.SA PPLA11.SA B3SA3.SA BOAS3.SA CIEL3.SA CARD3.SA', 'insurance': 'BRGE3.SA BBSE3.SA IRBR3.SA PSSA3.SA CSAB4.SA SULA4.SA APER3.SA WIZS3.SA', 'real_estate': 'ALSO3.SA BRML3.SA BRPR3.SA CORR4.SA CCPR3.SA GSHP3.SA HBTS5.SA HBRE3.SA IGBR3.SA IGTA3.SA JPSA3.SA LOGG3.SA MULT3.SA SCAR3.SA BBRK3.SA LPSB3.SA'}

# %% [markdown]
# # Read the Data

# %%
now = True

if now:
    startDate = datetime.date(2018, 1, 1)
    start1 = startDate - pd.Timedelta(days=365)
    end1 = datetime.date(2021, 4, 30) + pd.Timedelta(days=1)
    endDate = end1 - pd.Timedelta(days=365)
else:
    startDate = datetime.date(2009, 1, 1)
    start1 = startDate - pd.Timedelta(days=366)
    end1 = datetime.date(2014, 12, 31) + pd.Timedelta(days=1)
    endDate = end1 - pd.Timedelta(days=365)

what = 'Adj Close'
what = 'Close'

market_index = ['BOVA11.SA', 'IBOV11.SA']
filterTopStocks = True

checkADF = True

leverage = 1

useNegativePairs = True

longOnly = False

minSectorLen = 5
minPairCorrel = 0.0

riskFreeYearRet = 0.03
pairAmount = 1.0

debug = False
pairList = []

dataFolder = 'sector_data/'
if not os.path.exists(dataFolder):
    os.makedirs(dataFolder)

print('Loading Sectors data:')
print()

dfIndex = None
allSectors = dict(sectorTickers, **{ 'index' : market_index })
sectorsDataDic = {}
for sector in allSectors:
    tickers = allSectors[sector]

    print(f'Loading {sector} sector data...')

    dataName = dataFolder+'BR {} data {} {}.csv'.format(sector, start1.strftime('%Y-%m-%d'), end1.strftime('%Y-%m-%d'))
    if not os.path.exists(dataName):

        dfa = yf.download(tickers, start=start1, end=end1, interval='1d') #, group_by="ticker" )

        df = dfa[what].copy()

        df.to_csv(dataName, index=True, header=True)

    df = pd.read_csv(dataName, header=0,
                          index_col=0,
                          parse_dates=True)

    if sector in sectorTickers:
        sectorsDataDic[sector] = df
    else:
        dfIndex = df
# Out:
# Loading Sectors data:
#
# Loading oil sector data...
# [*********************100%%**********************]  9 of 9 completed
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['BRDT3.SA', 'DMMO3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading metal sector data...
# [*********************100%%**********************]  4 of 4 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMXM3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading steel sector data...
# [*********************100%%**********************]  5 of 5 completed
# Loading paper sector data...
# [*********************100%%**********************]  4 of 4 completed
# Loading transp_material sector data...
# [*********************100%%**********************]  7 of 7 completed
# Loading machines sector data...
# [*********************100%%**********************]  10 of 10 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INEP4.SA']: YFChartError("%ticker%: Data doesn't exist for startDate = 1483236000, endDate = 1619838000")
# Loading rail_roads sector data...
# [*********************100%%**********************]  3 of 3 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['RLOG3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading highways sector data...
# [*********************100%%**********************]  3 of 3 completed
# Loading storage sector data...
# [*********************100%%**********************]  2 of 2 completed
# Loading services sector data...
# [*********************100%%**********************]  6 of 6 completed
# Loading agriculture sector data...
# [*********************100%%**********************]  4 of 4 completed
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['TESA3.SA', 'FRTA3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading meat sector data...
# [*********************100%%**********************]  6 of 6 completed
# Loading food sector data...
# [*********************100%%**********************]  4 of 4 completed
# Loading construction sector data...
# [*********************100%%**********************]  25 of 25 completed
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['CALI4.SA', 'CRDE3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading fabric sector data...
# [*********************100%%**********************]  10 of 10 completed
# Loading clothes_shoes sector data...
# [*********************100%%**********************]  14 of 14 completed
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['HGTX3.SA', 'LLIS3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading education sector data...
# [*********************100%%**********************]  6 of 6 completed
# Loading car_rental sector data...
# [*********************100%%**********************]  4 of 4 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LCAM3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading retail sector data...
# [*********************100%%**********************]  10 of 10 completed
# ERROR:yfinance:
# 4 Failed downloads:
# ERROR:yfinance:['VVAR3.SA', 'LAME4.SA', 'BTOW3.SA', 'CNTO3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading hospitals sector data...
# [*********************100%%**********************]  10 of 10 completed
# ERROR:yfinance:
# 3 Failed downloads:
# ERROR:yfinance:['PARD3.SA', 'GNDI3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ERROR:yfinance:['MATD3.SA']: YFChartError("%ticker%: Data doesn't exist for startDate = 1483236000, endDate = 1619838000")
# Loading drugstores sector data...
# [*********************100%%**********************]  6 of 6 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PNVL4.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading it sector data...
# [*********************100%%**********************]  11 of 11 completed
# ERROR:yfinance:
# 3 Failed downloads:
# ERROR:yfinance:['LINX3.SA', 'MOSI3.SA', 'SQIA3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading telecom sector data...
# [*********************100%%**********************]  4 of 4 completed
# Loading electricity sector data...
# [*********************100%%**********************]  37 of 37 completed
# ERROR:yfinance:
# 6 Failed downloads:
# ERROR:yfinance:['OMGE3.SA', 'POWE3.SA', 'ENBR3.SA', 'EEEL4.SA', 'CEPE3.SA', 'CESP3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading water sector data...
# [*********************100%%**********************]  6 of 6 completed
# Loading banking sector data...
# [*********************100%%**********************]  21 of 21 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIDI4.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading financial_services sector data...
# [*********************100%%**********************]  6 of 6 completed
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['CARD3.SA', 'BOAS3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading insurance sector data...
# [*********************100%%**********************]  8 of 8 completed
# ERROR:yfinance:
# 3 Failed downloads:
# ERROR:yfinance:['WIZS3.SA', 'SULA4.SA', 'CSAB4.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Loading real_estate sector data...
# [**********************62%%****                  ]  10 of 16 completed
# $IGBR3.SA: possibly delisted; No price data found  (1d 2017-01-01 -> 2021-05-01)
# [*********************100%%**********************]  15 of 16 completed
# ERROR:yfinance:
# 7 Failed downloads:
# ERROR:yfinance:['IGTA3.SA', 'JPSA3.SA', 'BBRK3.SA', 'BRML3.SA', 'ALSO3.SA', 'CCPR3.SA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ERROR:yfinance:['IGBR3.SA']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2017-01-01 -> 2021-05-01)')
# Loading index sector data...
# [*********************100%%**********************]  2 of 2 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['IBOV11.SA']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")

# %% [markdown]
# # Dealing with Survivorship Bias

# %%
sectorsDataOk = {}
sectorsTickersOk = {}

top80PercTickers = 'ABEV3.SA AZUL4.SA BTOW3.SA B3SA3.SA BBSE3.SA BRML3.SA BBDC3.SA BBDC4.SA BRAP4.SA BBAS3.SA BRKM5.SA BRFS3.SA BPAC11.SA CRFB3.SA CCRO3.SA CMIG4.SA HGTX3.SA CIEL3.SA COGN3.SA CPLE6.SA CSAN3.SA CPFE3.SA CVCB3.SA CYRE3.SA ECOR3.SA ELET3.SA ELET6.SA EMBR3.SA ENBR3.SA ENGI11.SA ENEV3.SA EGIE3.SA EQTL3.SA EZTC3.SA FLRY3.SA GGBR4.SA GOAU4.SA GOLL4.SA NTCO3.SA HAPV3.SA HYPE3.SA IGTA3.SA GNDI3.SA IRBR3.SA ITSA4.SA ITUB4.SA JBSS3.SA JHSF3.SA KLBN11.SA RENT3.SA LCAM3.SA LAME4.SA LREN3.SA MGLU3.SA MRFG3.SA BEEF3.SA MRVE3.SA MULT3.SA PCAR3.SA PETR3.SA PETR4.SA BRDT3.SA PRIO3.SA QUAL3.SA RADL3.SA RAIL3.SA SBSP3.SA SANB11.SA CSNA3.SA SULA11.SA SUZB3.SA TAEE11.SA VIVT3.SA TIMS3.SA TOTS3.SA UGPA3.SA USIM5.SA VALE3.SA VVAR3.SA WEGE3.SA YDUQ3.SA'
top100Tickers = 'ABEV3.SA ALPA4.SA ALUP11.SA AMAR3.SA ARZZ3.SA AZUL4.SA B3SA3.SA BBAS3.SA BBDC3.SA BBDC4.SA BEEF3.SA BIDI11.SA BIDI4.SA BPAC11.SA BPAN4.SA BRAP4.SA BRDT3.SA BRFS3.SA BRKM5.SA BRSR6.SA BTOW3.SA CESP6.SA CMIG3.SA CMIG4.SA CPFE3.SA CPLE6.SA CRFB3.SA CSAN3.SA CSMG3.SA CSNA3.SA CVCB3.SA CYRE3.SA DTEX3.SA ECOR3.SA EGIE3.SA ELET3.SA ELET6.SA EMBR3.SA ENAT3.SA ENBR3.SA ENEV3.SA ENGI11.SA EQTL3.SA FLRY3.SA GFSA3.SA GGBR4.SA GNDI3.SA GOAU4.SA GOLL4.SA HAPV3.SA HGTX3.SA HYPE3.SA IGTA3.SA ITSA4.SA ITUB4.SA JBSS3.SA JHSF3.SA KLBN11.SA LAME3.SA LAME4.SA LCAM3.SA LIGT3.SA LINX3.SA LOGG3.SA LREN3.SA LWSA3.SA MEAL3.SA MGLU3.SA MOVI3.SA MRFG3.SA MRVE3.SA MULT3.SA MYPK3.SA NTCO3.SA PETR3.SA PETR4.SA POMO4.SA PRIO3.SA PSSA3.SA QUAL3.SA RADL3.SA RAPT4.SA RENT3.SA SANB11.SA SBSP3.SA SLCE3.SA SMLS3.SA SMTO3.SA SUZB3.SA TAEE11.SA TEND3.SA TIET11.SA TOTS3.SA TRPL4.SA TUPY3.SA UGPA3.SA USIM5.SA VALE3.SA VVAR3.SA WEGE3.SA'
top100Ticker3Yrs = 'ABEV3.SA ALPA4.SA ALSO3.SA ALUP11.SA AMAR3.SA ARZZ3.SA AZUL4.SA B3SA3.SA BBAS3.SA BBDC3.SA BBDC4.SA BBSE3.SA BEEF3.SA BIDI11.SA BIDI4.SA BPAC11.SA BPAN4.SA BRAP4.SA BRDT3.SA BRFS3.SA BRKM5.SA BRML3.SA BRSR6.SA BTOW3.SA CCRO3.SA CESP6.SA CIEL3.SA CMIG3.SA CMIG4.SA CNTO3.SA COGN3.SA CPFE3.SA CPLE6.SA CRFB3.SA CSAN3.SA CSMG3.SA CSNA3.SA CVCB3.SA CYRE3.SA DTEX3.SA ECOR3.SA EGIE3.SA ELET3.SA ELET6.SA EMBR3.SA ENAT3.SA ENBR3.SA ENEV3.SA ENGI11.SA EQTL3.SA EZTC3.SA FLRY3.SA GFSA3.SA GGBR4.SA GNDI3.SA GOAU4.SA GOLL4.SA HAPV3.SA HGTX3.SA HYPE3.SA IGTA3.SA IRBR3.SA ITSA4.SA ITUB4.SA JBSS3.SA JHSF3.SA KLBN11.SA LAME3.SA LAME4.SA LCAM3.SA LIGT3.SA LINX3.SA LOGG3.SA LREN3.SA LWSA3.SA MDIA3.SA MEAL3.SA MGLU3.SA MOVI3.SA MRFG3.SA MRVE3.SA MULT3.SA MYPK3.SA NEOE3.SA NTCO3.SA ODPV3.SA PCAR3.SA PETR3.SA PETR4.SA POMO4.SA PRIO3.SA PSSA3.SA QUAL3.SA RADL3.SA RAIL3.SA RAPT4.SA RENT3.SA SANB11.SA SAPR11.SA SBSP3.SA SEER3.SA SLCE3.SA SMLS3.SA SMTO3.SA SULA11.SA SUZB3.SA TAEE11.SA TEND3.SA TIET11.SA TIMS3.SA TOTS3.SA TRPL4.SA TUPY3.SA UGPA3.SA USIM5.SA VALE3.SA VIVT3.SA VLID3.SA VVAR3.SA WEGE3.SA WIZS3.SA YDUQ3.SA'

topTickers = top100Ticker3Yrs.split(' ') if now and filterTopStocks else None

for sector in sectorTickers:

    df = sectorsDataDic[sector]
    #print(df.head())

    df = df.fillna(method='ffill')

    df = df.dropna(axis=1)
    #print(df.head())

    if topTickers is not None:
        sTickers = list(df.columns)

        for ticker in sTickers:
            if ticker not in topTickers:
                df.drop(ticker, axis=1, inplace=True)

    sTickers = list(df.columns)

    if len(sTickers) >= minSectorLen:

        sectorsDataOk[sector] = df
        sectorsTickersOk[sector] = sTickers

        print(f"{sector} = ", "'{}'".format(' '.join(sTickers)))
# Out:
# oil =  'CSAN3.SA ENAT3.SA PETR4.SA PRIO3.SA UGPA3.SA'
# construction =  'CYRE3.SA EZTC3.SA GFSA3.SA JHSF3.SA MRVE3.SA TEND3.SA'
# electricity =  'CMIG4.SA CPFE3.SA EGIE3.SA ELET3.SA ENEV3.SA EQTL3.SA LIGT3.SA TRPL4.SA'
# banking =  'BBAS3.SA BBDC4.SA BPAN4.SA ITSA4.SA ITUB4.SA'

# %% [markdown]
# # Calulate Pairs Correlation

# %%
def calcSectorCorrelations(sector):

    df = sectorsDataOk[sector].loc[startDate:endDate]
    cols = list(df.columns)
    n = len(cols)

    sectorCorr = {}

    print(f'Calculating {sector} pairs correlations...')
    for i in range(n-1):
        for j in range(i+1, n):

            pair = (cols[i], cols[j])

            corr = df[cols[i]].corr(df[cols[j]])

            if abs(corr) >= minPairCorrel:
                sectorCorr[pair] = corr

            #print(pair, f'corr: {sectorCorr[pair]:.4f}')

    return sectorCorr


sectorsCorrDic = {}

sectorQty = 0
pairQty = 0
for sector in sectorsDataOk:
    sectorCorrDic = calcSectorCorrelations(sector)

    #print(f"{sector} correlations = ", sectorCorrDic)
    print(f"{sector} correlations: ")

    pairs = sectorCorrDic.keys()
    corrs = sectorCorrDic.values()

    corrSorted = sorted(zip(corrs,pairs), reverse=True)
    sectorsCorrDic[sector] = corrSorted

    sectorQty += 1
    for corr in corrSorted:
        print( f'{corr[1]}: {corr[0]:.4f}')
        pairQty += 1

print()
print('sectors:', sectorQty)
print('pairs:', pairQty)
# Out:
# Calculating oil pairs correlations...
# oil correlations:
# ('CSAN3.SA', 'PRIO3.SA'): 0.9114
# ('PETR4.SA', 'PRIO3.SA'): 0.5379
# ('ENAT3.SA', 'PETR4.SA'): 0.5159
# ('ENAT3.SA', 'PRIO3.SA'): 0.5081
# ('CSAN3.SA', 'PETR4.SA'): 0.4677
# ('CSAN3.SA', 'ENAT3.SA'): 0.3636
# ('ENAT3.SA', 'UGPA3.SA'): -0.0745
# ('PETR4.SA', 'UGPA3.SA'): -0.0883
# ('CSAN3.SA', 'UGPA3.SA'): -0.1639
# ('PRIO3.SA', 'UGPA3.SA'): -0.2711
# Calculating construction pairs correlations...
# construction correlations:
# ('EZTC3.SA', 'JHSF3.SA'): 0.9829
# ('CYRE3.SA', 'EZTC3.SA'): 0.9642
# ('CYRE3.SA', 'JHSF3.SA'): 0.9408
# ('EZTC3.SA', 'TEND3.SA'): 0.9392
# ('JHSF3.SA', 'TEND3.SA'): 0.9354
# ('CYRE3.SA', 'TEND3.SA'): 0.9236
# ('CYRE3.SA', 'MRVE3.SA'): 0.9213
# ('EZTC3.SA', 'MRVE3.SA'): 0.8542
# ('MRVE3.SA', 'TEND3.SA'): 0.8441
# ('JHSF3.SA', 'MRVE3.SA'): 0.8244
# ('CYRE3.SA', 'GFSA3.SA'): -0.4102
# ('GFSA3.SA', 'JHSF3.SA'): -0.4267
# ('GFSA3.SA', 'MRVE3.SA'): -0.4539
# ('EZTC3.SA', 'GFSA3.SA'): -0.4615
# ('GFSA3.SA', 'TEND3.SA'): -0.5578
# Calculating electricity pairs correlations...
# electricity correlations:
# ('CPFE3.SA', 'EGIE3.SA'): 0.9518
# ('ENEV3.SA', 'EQTL3.SA'): 0.9440
# ('CPFE3.SA', 'EQTL3.SA'): 0.9311
# ('EGIE3.SA', 'EQTL3.SA'): 0.9262
# ('CMIG4.SA', 'ELET3.SA'): 0.9238
# ('ELET3.SA', 'TRPL4.SA'): 0.9202
# ('EGIE3.SA', 'ELET3.SA'): 0.9051
# ('EGIE3.SA', 'TRPL4.SA'): 0.9014
# ('CPFE3.SA', 'ELET3.SA'): 0.8969
# ('CMIG4.SA', 'CPFE3.SA'): 0.8893
# ('CMIG4.SA', 'EGIE3.SA'): 0.8769
# ('EGIE3.SA', 'ENEV3.SA'): 0.8536
# ('CPFE3.SA', 'TRPL4.SA'): 0.8496
# ('CMIG4.SA', 'TRPL4.SA'): 0.8435
# ('CPFE3.SA', 'ENEV3.SA'): 0.8407
# ('EQTL3.SA', 'TRPL4.SA'): 0.8387
# ('ELET3.SA', 'LIGT3.SA'): 0.8354
# ('CMIG4.SA', 'LIGT3.SA'): 0.8346
# ('ELET3.SA', 'EQTL3.SA'): 0.8138
# ('CPFE3.SA', 'LIGT3.SA'): 0.7928
# ('EGIE3.SA', 'LIGT3.SA'): 0.7806
# ('CMIG4.SA', 'EQTL3.SA'): 0.7493
# ('ENEV3.SA', 'TRPL4.SA'): 0.7248
# ('EQTL3.SA', 'LIGT3.SA'): 0.7248
# ('LIGT3.SA', 'TRPL4.SA'): 0.7200
# ('ELET3.SA', 'ENEV3.SA'): 0.6540
# ('CMIG4.SA', 'ENEV3.SA'): 0.5857
# ('ENEV3.SA', 'LIGT3.SA'): 0.5484
# Calculating banking pairs correlations...
# banking correlations:
# ('BBAS3.SA', 'BBDC4.SA'): 0.9775
# ('ITSA4.SA', 'ITUB4.SA'): 0.9319
# ('BBDC4.SA', 'ITSA4.SA'): 0.8943
# ('BBDC4.SA', 'ITUB4.SA'): 0.8940
# ('BBAS3.SA', 'ITSA4.SA'): 0.8922
# ('BBAS3.SA', 'ITUB4.SA'): 0.8692
# ('BPAN4.SA', 'ITSA4.SA'): 0.5616
# ('BBAS3.SA', 'BPAN4.SA'): 0.5477
# ('BBDC4.SA', 'BPAN4.SA'): 0.5141
# ('BPAN4.SA', 'ITUB4.SA'): 0.3136
#
# sectors: 4
# pairs: 63

# %% [markdown]
# # Calculate Pairs Cointegration

# %%
sigPos = { 90: 0, 95: 1, 99: 2 }

significance=90

def calcCointegration(df, pair, significance=99 ):

    # Combine the two time series into a matrix y2 for input into Johansen test
    y2=pd.concat([df[pair[0]], df[pair[1]]], axis=1)
    y2=y2.loc[y2.notnull().all(axis=1),]

    if (y2.shape[0] > 240):
        # Johansen test
        result=vm.coint_johansen(y2.values, det_order=0, k_ar_diff=1)
        isCoint = (result.lr1[0] > result.cvt[0, sigPos[significance]])
        if False: #isCoint:
            print( pair )
            print(result.lr1)
            print(result.cvt)
            print(result.evec)
            print()
    else:
        isCoint = False

    return isCoint, result

def cointRel(result, significance=99):
    return result.lr1[0] / result.cvt[0, sigPos[significance]]

sectorsCointPairs = {}

for sector in sectorsDataOk:

    print(f'Calculating {sector} pairs cointegrations...')

    df = sectorsDataOk[sector].loc[:endDate]

    corrs = sectorsCorrDic[sector]

    sectorCointPairs = []
    for corrPair in corrs:
        isCoint, result = calcCointegration(df, corrPair[1], significance)
        if isCoint:
            sectorCointPairs.append((corrPair[1], result))

    if len(sectorCointPairs) > 0:
        sectorsCointPairs[sector] = sectorCointPairs


sectorsCointPairsSorted = {}
for sector in sectorsCointPairs:

    print( f'Sorting sector {sector}...')

    sectorsCointPairsSorted[sector] = sorted(sectorsCointPairs[sector], key=lambda x: cointRel(x[1], significance), reverse=True)

sectorQty = 0
pairQty = 0
lastPairQty = 0
for sector in sectorsCointPairs:
    print( f'{sector}:')
    for pair, result in sectorsCointPairsSorted[sector]:
        #print( f'{pair}\n{result.evec}')
        #print( f'{pair}\n{result.evec[:,0]}')
        #print( f'{pair} [{result.evec[0][0]:.4f}, {result.evec[1][0]:.4f}]')
        rel = result.evec[0][0]/result.evec[1][0]
        if rel >= 0:
            print( f'{pair[0]} + {rel:.4f} * {pair[1]}')
        else:
            print( f'{pair[0]} - {-rel:.4f} * {pair[1]}')
        pairQty += 1

    if lastPairQty != pairQty:
        lastPairQty = pairQty
        sectorQty += 1

print()
print('sectors:', sectorQty)
print('pairs:', pairQty)
# Out:
# Calculating oil pairs cointegrations...
# Calculating construction pairs cointegrations...
# Calculating electricity pairs cointegrations...
# Calculating banking pairs cointegrations...
# Sorting sector oil...
# Sorting sector construction...
# Sorting sector electricity...
# Sorting sector banking...
# oil:
# ENAT3.SA - 2.5554 * PRIO3.SA
# construction:
# CYRE3.SA - 0.4529 * MRVE3.SA
# MRVE3.SA - 3.6933 * TEND3.SA
# EZTC3.SA - 0.2177 * MRVE3.SA
# JHSF3.SA - 1.3180 * MRVE3.SA
# EZTC3.SA - 0.1548 * JHSF3.SA
# electricity:
# EGIE3.SA - 1.1075 * ELET3.SA
# CMIG4.SA - 5.6028 * EGIE3.SA
# CMIG4.SA - 6.1303 * ELET3.SA
# ELET3.SA - 0.3377 * TRPL4.SA
# CMIG4.SA - 2.6071 * CPFE3.SA
# banking:
# BBAS3.SA - 0.9542 * BBDC4.SA
# ITSA4.SA - 3.1404 * ITUB4.SA
# BBDC4.SA - 0.9609 * BPAN4.SA
# BBAS3.SA - 0.9338 * ITUB4.SA
#
# sectors: 4
# pairs: 15

# %% [markdown]
# # Calculate Pairs Spread and Beta

# %%
dfI = dfIndex['BOVA11.SA'].loc[startDate:endDate]
indexVariance = dfI.var()

sectorQty = 0
pairQty = 0
lastPairQty = 0

pairSpreadData = {}
pairSpreadBeta = {}
for sector in sectorsCointPairs:

    df = sectorsDataOk[sector]

    print( f'Calculating spreads for sector {sector}...')
    for pair, result in sectorsCointPairsSorted[sector]:

        rel = result.evec[0][0]/result.evec[1][0]

        dfSpread = df[pair[0]] + rel * df[pair[1]]

        dfSpread = pd.DataFrame(dfSpread, columns=['spread'])
        dfSpread['neg'] = dfSpread.apply(lambda y: 1 if y['spread'] < 0 else 0, axis=1 )
        dfSpread['pos'] = dfSpread.apply(lambda y: 1 if y['spread'] > 0 else 0, axis=1 )

        allPositive = dfSpread['neg'].sum() == 0
        allNegative = dfSpread['pos'].sum() == 0

        if ( allPositive or
           ( allNegative and useNegativePairs)):

            if allNegative and useNegativePairs:
                pairSpreadData[pair] = -dfSpread
            else:
                pairSpreadData[pair] = dfSpread

            pairSpreadData[pair][pair[0]] = df[pair[0]]
            pairSpreadData[pair][pair[1]] = df[pair[1]]

            beta = dfI.cov(dfSpread.loc[startDate:endDate, 'spread'])/indexVariance

            pairSpreadBeta[pair] = beta

            print(pair, f'beta={beta:5.2f}')

            pairQty += 1

    if lastPairQty != pairQty:
        lastPairQty = pairQty
        sectorQty += 1

print()
print('sectors:', sectorQty)
print('pairs:', pairQty)
# Out:
# Calculating spreads for sector oil...
# Calculating spreads for sector construction...
# ('CYRE3.SA', 'MRVE3.SA') beta= 0.38
# ('MRVE3.SA', 'TEND3.SA') beta=-1.46
# ('EZTC3.SA', 'MRVE3.SA') beta= 0.78
# ('JHSF3.SA', 'MRVE3.SA') beta=-0.19
# ('EZTC3.SA', 'JHSF3.SA') beta= 0.81
# Calculating spreads for sector electricity...
# ('CMIG4.SA', 'EGIE3.SA') beta=-3.03
# ('CMIG4.SA', 'ELET3.SA') beta=-4.11
# ('ELET3.SA', 'TRPL4.SA') beta= 0.61
# ('CMIG4.SA', 'CPFE3.SA') beta=-0.80
# Calculating spreads for sector banking...
# ('ITSA4.SA', 'ITUB4.SA') beta=-0.61
# ('BBDC4.SA', 'BPAN4.SA') beta= 0.04
# ('BBAS3.SA', 'ITUB4.SA') beta= 0.09
#
# sectors: 3
# pairs: 12

# %% [markdown]
# # Calculate Pairs Halflife

# %%
masxHalflife = 60

sectorQty = 0
pairQty = 0
lastPairQty = 0

pairSpreadHalflife = {}
for sector in sectorsCointPairs:

    print( f'{sector}:')
    for pair, result in sectorsCointPairsSorted[sector]:

        if pair in pairSpreadData:
            dfa = pairSpreadData[pair]
            df = pairSpreadData[pair].loc[startDate:endDate]

            yport=df['spread']
            ylag=yport.shift()
            deltaY=yport-ylag
            df2=pd.concat([ylag, deltaY], axis=1)
            df2.columns=['ylag', 'deltaY']
            regress_results=sm.ols(formula="deltaY ~ ylag", data=df2).fit() # Note this can deal with NaN in top row
            #print(regress_results.params)

            halflife=-np.log(2)/regress_results.params['ylag']

            #  Apply a simple linear mean reversion strategy to EWA-EWC-IGE
            lookback=np.round(halflife).astype(int) #  setting lookback to the halflife found above
            if lookback < 0:
                #print(pair, 'halflife=%.2f days' % halflife)
                #print(pair, 'halflife < 0!!!!!!!!!!!!!!!!!!!!')
                lookback = -lookback
            else:
                if lookback <= masxHalflife:
                    print(pair, 'halflife=%.2f days' % halflife)
                    pairSpreadHalflife[pair] = lookback

                    pairQty += 1

    if lastPairQty != pairQty:
        lastPairQty = pairQty
        sectorQty += 1

print()
print('sectors:', sectorQty)
print('pairs:', pairQty)
# Out:
# oil:
# construction:
# ('JHSF3.SA', 'MRVE3.SA') halflife=34.44 days
# electricity:
# banking:
# ('BBAS3.SA', 'ITUB4.SA') halflife=40.38 days
#
# sectors: 2
# pairs: 2

# %% [markdown]
# # Bollinger Band Statistical Arbitrage Strategy

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm

# Function to calculate drawdown
def calculate_drawdown(equity_curve):
    hwm = [0]
    drawdown = np.zeros(len(equity_curve))
    for t in range(1, len(equity_curve)):
        hwm.append(max(hwm[t-1], equity_curve.iloc[t-1]))
        if hwm[t] != 0:
            drawdown[t] = (hwm[t] - equity_curve.iloc[t]) / hwm[t]
    return drawdown

# Function to calculate annualized volatility
def calculate_volatility(returns):
    return np.std(returns) * np.sqrt(252)

# Example initialization for demonstration:
# df = pd.DataFrame({'cumpnl_spread': np.random.randn(100)})  # Replace with your actual DataFrame

# Initialize additional columns in DataFrame
df['drawdown'] = 0.0
df['volatility'] = 0.0
df['stop_loss_triggered'] = False
df['positions_prev'] = 0  # Assuming this column is initialized here

# Calculate returns, drawdown, and volatility
for i in range(1, len(df)):
    df.loc[i, 'drawdown'] = calculate_drawdown(df['cumpnl_spread'][:i+1])[-1] # Make sure the slice is correct
    df.loc[i, 'volatility'] = calculate_volatility(df['cumpnl_spread'].pct_change().dropna()[:i+1])

    # Check for stop-loss condition
    if df.loc[i, 'cumpnl_spread'] < -stop_loss:
        df.loc[i, 'stop_loss_triggered'] = True
        df.loc[i, 'positions_prev'] = 0  # Exit position

# Plot drawdown and volatility
df[['cumpnl_spread', 'drawdown', 'volatility']].plot(figsize=(12, 8), subplots=True, title='Risk Metrics')

# Adjust trading logic to include drawdown and volatility checks
for index, row in df.iterrows():  # Iterate using .iterrows()
    if row['drawdown'] > max_drawdown:
        df.loc[index, 'positions_prev'] = 0  # Exit position
    if row['volatility'] > volatility_threshold:
        df.loc[index, 'positions_prev'] = 0  # Exit position

# Print the adjusted trading statistics
print(pair, 'Cumulative pnl %7.2f The Sharpe Ratio %5.2f Max Drawdown %5.2f Volatility %5.2f' %
      (df['cumpnl_spread'].iloc[-1], s, df['drawdown'].max(), df['volatility'].max()))

# Define other functions and trading logic

adfSignificance = 90

sigAdfPos = { 90: '10%', 95: '5%', 99: '1%' }

def adfValCond1(s, td, pd, adfDays):
    if pd > td:
        pd = 0

    for ad in adfDays:
        if ad > pd and ad <= td:
            return s
    return 0.0

def adfVal(w):
    x = adfuller(w, maxlag = 1)
    return x[0]-x[4][sigAdfPos[adfSignificance]]

def adfValPos(w, l, df, adfLen):
    l = int(l)
    if l >= adfLen-1:
        x = adfuller(df.iloc[l-adfLen+1:l+1][w], maxlag = 1)
        adf = x[0]-x[4][sigAdfPos[adfSignificance]]
        return adf
    return 0.0

def adfValCond(w, l, df, adfDays, adfLen):
    l = int(l)
    td = df.iloc[l]['day']
    pd = df.iloc[l-1]['day'] if l > 0 else td
    if pd > td:
        pd = 0

    for ad in adfDays:
        if ad > pd and ad <= td:
            if l >= adfLen-1:
                x = adfuller(df.iloc[l-adfLen+1:l+1][w], maxlag = 1)
                adf = x[0]-x[4][sigAdfPos[adfSignificance]]
                return adf
    return 0.0

def calcQtyBalAmt(df, index, prev, price, position, spread):
    qty = df.loc[prev]['trade_qty']
    balance = df.loc[prev]['balance']
    if price > 0.0:
        if position > 0:
            if qty == 0.0:
                qty = leverage * balance / price
                df.loc[index, 'trade_qty'] = qty
                balance -= qty * price
            else:
                qty = -qty
                balance -= price * qty
                qty = leverage * balance / price
                df.loc[index, 'trade_qty'] = qty
                balance -= price * qty
        elif position == 0:
            balance -= -price * qty
            qty = 0
            df.loc[index, 'trade_qty'] = qty
        else:
            pass
    elif price == 0.0:
        df.loc[index, 'trade_qty'] = qty
    elif price < 0.0:
        if position == 0:
            balance += -price * qty
            qty = 0
            df.loc[index, 'trade_qty'] = qty
        elif position < 0:
            if qty == 0.0:
                qty = leverage * balance / price
                df.loc[index, 'trade_qty'] = qty
                balance += price * qty
            else:
                qty = -qty
                balance += 2 * price * qty
                df.loc[index, 'trade_qty'] = qty
        else:
            pass
    df.loc[index, 'balance'] = balance
    df.loc[index, 'position_amt'] = price * qty / leverage if position > 0 else balance if position == 0 else balance/(1+leverage)
    df.loc[index, 'mtm_amt'] = spread * qty / leverage if position > 0 else balance if position == 0 else price*qty-(leverage*qty*(spread+price))

def stat_arb(df, what, lookback, std_dev, start=None, end=None, adfDays=[], adfLen=252):
    startIsNone = start is None
    if start is None:
        start = df.index[0]
    else:
        start = df.loc[start:].index[0]
    if end is None:
        end = df.index[-1]
    else:
        end = df.loc[:end].index[-1]

    df['moving_average'] = df[what].rolling(lookback).mean()
    df['moving_std_dev'] = df[what].rolling(lookback).std()
    df['upper_band'] = df.moving_average + std_dev*df.moving_std_dev
    df['lower_band'] = df.moving_average - std_dev*df.moving_std_dev
    df['moving_avg_prev'] = df['moving_average'].shift(1)
    df['upper_band_prev'] = df['upper_band'].shift(1)
    df['lower_band_prev'] = df['lower_band'].shift(1)
    df['date']=[ d for d in list(df.index) ]
    prev_date = [df.index[0]] + [ d for d in list(df.index[:-1]) ]
    df['prev_date']=prev_date
    if checkADF:
        df['day']=[ d.day for d in list(df.index) ]
        if False:
            prev_day = [0] + [ d.day for d in list(df.index[:-1]) ]
            df['prev_day']=prev_day
            df['adf_score'] = df[what].rolling(window=adfTestWindowLen).apply(lambda x: adfVal(x))
            df['adf_score_cond'] = df[['adf_score', 'day', 'prev_day']].apply(lambda x: adfValCond1(x['adf_score'], x['day'], x['prev_day'], adfDays), axis=1)
        else:
            df['pos']=[ d for d in list(df.reset_index().index) ]
            df['adf_score_cond'] = df[[what, 'pos']].apply(lambda x: adfValCond(what, x['pos'], df, adfDays, adfLen), axis=1)
    else:
        df['adf_score'] = 0.0
        df['adf_score_cond'] = 0.0
    df['prev'] = df[what].shift(1)
    df['long_entry'] = df.apply(lambda y: y[what] < y['lower_band'] and y['prev'] >= y['lower_band_prev'] , axis=1 )
    df['long_exit'] = df.apply(lambda y: y[what] >= y['moving_average'] and y['prev'] < y['moving_avg_prev'] , axis=1 )
    df['short_entry'] = df.apply(lambda y: y[what] > y['upper_band'] and y['prev'] <= y['upper_band_prev'] , axis=1 )
    df['short_exit'] = df.apply(lambda y: y[what] <= y['moving_average'] and y['prev'] > y['moving_avg_prev'] , axis=1 )
    df['positions_prev'] = 0
    df['trade_qty'] = 0
    df['balance'] = 100.0
    df['position_amt'] = 0
    df['mtm_amt'] = 0
    df['spread_pnl'] = 0
    df['cumpnl_spread'] = 0

    for i in range(len(df)):
        if i > 0:
            prev = i-1
            if df.index[i] >= start:
                if checkADF:
                    if df.loc[i]['adf_score_cond'] > 0.0:
                        if df.loc[prev]['positions_prev'] == 0:
                            if df.loc[i]['long_entry']:
                                df.loc[i, 'positions_prev'] = 1
                            elif df.loc[i]['short_entry']:
                                df.loc[i, 'positions_prev'] = -1
                            else:
                                df.loc[i, 'positions_prev'] = 0
                        elif df.loc[prev]['positions_prev'] > 0: # Long
                            if df.loc[i]['long_exit']:
                                df.loc[i, 'positions_prev'] = 0
                            else:
                                df.loc[i, 'positions_prev'] = 1
                        elif df.loc[prev]['positions_prev'] < 0: # Short
                            if df.loc[i]['short_exit']:
                                df.loc[i, 'positions_prev'] = 0
                            else:
                                df.loc[i, 'positions_prev'] = -1
                    else:
                        df.loc[i, 'positions_prev'] = 0
                else:
                    if df.loc[prev]['positions_prev'] == 0:
                        if df.loc[i]['long_entry']:
                            df.loc[i, 'positions_prev'] = 1
                        elif df.loc[i]['short_entry']:
                            df.loc[i, 'positions_prev'] = -1
                        else:
                            df.loc[i, 'positions_prev'] = 0
                    elif df.loc[prev]['positions_prev'] > 0: # Long
                        if df.loc[i]['long_exit']:
                            df.loc[i, 'positions_prev'] = 0
                        else:
                            df.loc[i, 'positions_prev'] = 1
                    elif df.loc[prev]['positions_prev'] < 0: # Short
                        if df.loc[i]['short_exit']:
                            df.loc[i, 'positions_prev'] = 0
                        else:
                            df.loc[i, 'positions_prev'] = -1
                calcQtyBalAmt(df, i, prev, df.loc[i][what], df.loc[i]['positions_prev'], df.loc[i]['spread'])
                df.loc[i, 'spread_pnl'] = df.loc[i]['mtm_amt'] - df.loc[prev]['mtm_amt']
                df.loc[i, 'cumpnl_spread'] = df.loc[i, 'spread_pnl'] + df.loc[prev]['cumpnl_spread']
                if df.loc[i]['positions_prev'] == 0:
                    df.loc[i, 'trade_qty'] = 0
                    df.loc[i, 'position_amt'] = 0
                    df.loc[i, 'mtm_amt'] = df.loc[i]['balance']
    return df

# Existing code for trading pairs and other logic
pairs = [ ('SPY', 'IWM'), ('GLD', 'GDX') ]

lookback = 42
std_dev = 2
adfDays=[20, 21, 22]
adfLen = 252

for pair in pairs:
    df = merge(pair, hist_data)
    df['spread'] = df[pair[0]] - df[pair[1]]
    checkADF = False
    df = stat_arb(df, 'spread', lookback, std_dev, adfDays=adfDays, adfLen=adfLen)
    print(pair, 'Cumulative pnl %7.2f The Sharpe Ratio %5.2f' % (df['cumpnl_spread'].iloc[-1], df['cumpnl_spread'].mean()/df['cumpnl_spread'].std()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c9bf3b2e80b5> in <cell line: 44>()
#      43 # Adjust trading logic to include drawdown and volatility checks
#      44 for index, row in df.iterrows():  # Iterate using .iterrows()
# ---> 45     if row['drawdown'] > max_drawdown:
#      46         df.loc[index, 'positions_prev'] = 0  # Exit position
#      47     if row['volatility'] > volatility_threshold:
#
# TypeError: '>' not supported between instances of 'NaTType' and 'float'

# %% [markdown]
# # Calculate Grid Search Pairs Returns

# %%
useCumRet = True
usePosAmt = True

std_dev=1

if checkADF:
    adfTestWindowLen = [ 126, 252, 378, 504 ]
    adfCheckDays = [ [1], [1, 16], [1, 11, 21] ]
else:
    adfTestWindowLen = [ 252 ]
    adfCheckDays = [ [1] ]

pairSpreadReturnSets = {}
for adfLen in adfTestWindowLen:
    for adfDays in adfCheckDays:
        opt = (adfLen, '-'.join([str(a) for a in adfDays]))
        print()
        print(f'Checking ADF with length {adfLen//21} months every month on day{"s" if len(adfDays)>1 else ""} {adfDays} from {endDate} to {end1}')

        pairSpreadReturns = {}
        for pair in pairSpreadHalflife:

            lookback = pairSpreadHalflife[pair]

            dfa = pairSpreadData[pair]

            dfa = stat_arb(dfa, 'spread', lookback=lookback, std_dev=std_dev, start=endDate, end=None, adfDays=adfDays, adfLen=adfLen)

            df = dfa.loc[endDate:]

            s = (np.mean(df['pnl_spread'])-(riskFreeYearRet/252))/np.std(df['pnl_spread'])*(252**0.5)
            print(pair, 'Cumulative pnl %6.2f The Sharpe Ratio %5.2f' % (df['cumpnl_spread'].iloc[-1], s))

            sr = (np.mean(df['ret_spread']))/np.std(df['ret_spread'])*(252**0.5)
            print(pair, 'Cumulative ret %6.2f The Sharpe Ratio %5.2f' % (df['cumret_spread'].iloc[-1], sr))

            sp = (np.mean(df['position_gain']))/np.std(df['position_gain'])*(252**0.5)
            print(pair, 'Final Position %6.2f The Sharpe Ratio %5.2f' % (df['position_amt'].iloc[-1], sp))
            print()


            if usePosAmt:
                pairSpreadReturns[pair] = (df['position_amt'].iloc[-1]-pairAmount, sp)
            elif useCumRet:
                pairSpreadReturns[pair] = (df['cumret_spread'].iloc[-1], sr)
            else:
                pairSpreadReturns[pair] = (df['cumpnl_spread'].iloc[-1], s)

        pairSpreadReturnSets[opt] = pairSpreadReturns
# Out:
# Checking ADF with length 6 months every month on day [1] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.52 The Sharpe Ratio  1.12
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.55 The Sharpe Ratio  1.87
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.55 The Sharpe Ratio  1.48
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl   0.65 The Sharpe Ratio  0.99
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret   0.45 The Sharpe Ratio  1.40
# ('BBAS3.SA', 'ITUB4.SA') Final Position   1.45 The Sharpe Ratio  1.38
#
#
# Checking ADF with length 6 months every month on days [1, 16] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.40 The Sharpe Ratio  0.95
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.38 The Sharpe Ratio  1.24
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.38 The Sharpe Ratio  1.29
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl   0.37 The Sharpe Ratio  0.57
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret   0.20 The Sharpe Ratio  0.74
# ('BBAS3.SA', 'ITUB4.SA') Final Position   1.20 The Sharpe Ratio  1.14
#
#
# Checking ADF with length 6 months every month on days [1, 11, 21] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.54 The Sharpe Ratio  1.28
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.56 The Sharpe Ratio  1.87
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.56 The Sharpe Ratio  1.51
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl   0.26 The Sharpe Ratio  0.42
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret   0.10 The Sharpe Ratio  0.48
# ('BBAS3.SA', 'ITUB4.SA') Final Position   1.10 The Sharpe Ratio  1.05
#
#
# Checking ADF with length 12 months every month on day [1] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.65 The Sharpe Ratio  1.36
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.72 The Sharpe Ratio  2.23
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.72 The Sharpe Ratio  1.65
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl   0.04 The Sharpe Ratio  0.02
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.34 The Sharpe Ratio -0.29
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.66 The Sharpe Ratio  0.58
#
#
# Checking ADF with length 12 months every month on days [1, 16] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.53 The Sharpe Ratio  1.29
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.50 The Sharpe Ratio  1.52
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.50 The Sharpe Ratio  1.42
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl  -0.26 The Sharpe Ratio -0.49
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.55 The Sharpe Ratio -0.59
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.45 The Sharpe Ratio  0.38
#
#
# Checking ADF with length 12 months every month on days [1, 11, 21] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.59 The Sharpe Ratio  1.52
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.61 The Sharpe Ratio  1.90
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.61 The Sharpe Ratio  1.55
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl  -0.42 The Sharpe Ratio -0.75
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.59 The Sharpe Ratio -0.83
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.41 The Sharpe Ratio  0.36
#
#
# Checking ADF with length 18 months every month on day [1] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.65 The Sharpe Ratio  1.36
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.72 The Sharpe Ratio  2.23
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.72 The Sharpe Ratio  1.65
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl   0.18 The Sharpe Ratio  0.22
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.19 The Sharpe Ratio -0.01
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.81 The Sharpe Ratio  0.71
#
#
# Checking ADF with length 18 months every month on days [1, 16] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.53 The Sharpe Ratio  1.29
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.50 The Sharpe Ratio  1.52
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.50 The Sharpe Ratio  1.42
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl  -0.12 The Sharpe Ratio -0.22
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.33 The Sharpe Ratio -0.36
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.67 The Sharpe Ratio  0.58
#
#
# Checking ADF with length 18 months every month on days [1, 11, 21] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.46 The Sharpe Ratio  1.21
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.42 The Sharpe Ratio  1.47
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.42 The Sharpe Ratio  1.38
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl  -0.17 The Sharpe Ratio -0.31
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.35 The Sharpe Ratio -0.44
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.65 The Sharpe Ratio  0.56
#
#
# Checking ADF with length 24 months every month on day [1] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.65 The Sharpe Ratio  1.34
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.75 The Sharpe Ratio  2.59
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.75 The Sharpe Ratio  1.70
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl   0.02 The Sharpe Ratio -0.01
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.28 The Sharpe Ratio -0.24
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.72 The Sharpe Ratio  0.64
#
#
# Checking ADF with length 24 months every month on days [1, 16] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.58 The Sharpe Ratio  1.39
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.57 The Sharpe Ratio  1.65
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.57 The Sharpe Ratio  1.48
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl  -0.00 The Sharpe Ratio -0.05
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.28 The Sharpe Ratio -0.24
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.72 The Sharpe Ratio  0.63
#
#
# Checking ADF with length 24 months every month on days [1, 11, 21] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   0.46 The Sharpe Ratio  1.17
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret   0.42 The Sharpe Ratio  1.46
# ('JHSF3.SA', 'MRVE3.SA') Final Position   1.42 The Sharpe Ratio  1.37
#
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl  -0.10 The Sharpe Ratio -0.20
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret  -0.36 The Sharpe Ratio -0.47
# ('BBAS3.SA', 'ITUB4.SA') Final Position   0.64 The Sharpe Ratio  0.59

# %% [markdown]
# # Find Best Returns Combination

# %%
topLen = 10

sortFieldPos = { 'pnl': 0, 'sr': 1 }

sortField = 'sr'

pairSpreadReturnsSorted = {}

for opt in pairSpreadReturnSets:

    pairSpreadReturns = pairSpreadReturnSets[opt]

    pairs = list(pairSpreadReturns.keys())
    rets = list(pairSpreadReturns.values())

    pos = sortFieldPos[sortField]

    pairSpreadReturnsSorted[opt] = sorted(zip(pairs, rets), key=lambda x: x[1][pos], reverse=True)[:topLen]


max_pnl = 0
max_sr = 0
for opt in pairSpreadReturnsSorted:

    print()
    print(f'Top {topLen} results from ADF length {opt[0]/21} months checking on day{"s" if len(opt[1])>1 else ""} {opt[1]} ')

    pnls = []
    srs = []
    for pr in pairSpreadReturnsSorted[opt]:
        pnl = pr[1][0]
        sr = pr[1][1]
        print(pr[0], f'PnL={pnl:6.2f} Sharpe={sr:5.2f}')

        pnls.append(pnl)
        srs.append(sr)

    pnl_std = np.std(pnls)
    pnl_avg = np.mean(pnls)

    if pnl_avg > max_pnl:
        max_pnl = pnl_avg
        max_pnl_opt = opt

    sr_std = np.std(srs)
    sr_avg = np.mean(srs)

    if sr_avg > max_sr:
        max_sr = sr_avg
        max_sr_opt = opt


    print(f'PnL avg={pnl_avg:6.2f} PnL stddev={pnl_std:6.2f}')
    print(f'ShR avg={sr_avg:6.2f} ShR stddev={sr_std:6.2f}')
# Out:
# Top 10 results from ADF length 6.0 months checking on day 1
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.55 Sharpe= 1.48
# ('BBAS3.SA', 'ITUB4.SA') PnL=  0.45 Sharpe= 1.38
# PnL avg=  0.50 PnL stddev=  0.05
# ShR avg=  1.43 ShR stddev=  0.05
#
# Top 10 results from ADF length 6.0 months checking on days 1-16
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.38 Sharpe= 1.29
# ('BBAS3.SA', 'ITUB4.SA') PnL=  0.20 Sharpe= 1.14
# PnL avg=  0.29 PnL stddev=  0.09
# ShR avg=  1.21 ShR stddev=  0.07
#
# Top 10 results from ADF length 6.0 months checking on days 1-11-21
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.56 Sharpe= 1.51
# ('BBAS3.SA', 'ITUB4.SA') PnL=  0.10 Sharpe= 1.05
# PnL avg=  0.33 PnL stddev=  0.23
# ShR avg=  1.28 ShR stddev=  0.23
#
# Top 10 results from ADF length 12.0 months checking on day 1
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.72 Sharpe= 1.65
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.34 Sharpe= 0.58
# PnL avg=  0.19 PnL stddev=  0.53
# ShR avg=  1.11 ShR stddev=  0.53
#
# Top 10 results from ADF length 12.0 months checking on days 1-16
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.50 Sharpe= 1.42
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.55 Sharpe= 0.38
# PnL avg= -0.02 PnL stddev=  0.53
# ShR avg=  0.90 ShR stddev=  0.52
#
# Top 10 results from ADF length 12.0 months checking on days 1-11-21
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.61 Sharpe= 1.55
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.59 Sharpe= 0.36
# PnL avg=  0.01 PnL stddev=  0.60
# ShR avg=  0.95 ShR stddev=  0.59
#
# Top 10 results from ADF length 18.0 months checking on day 1
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.72 Sharpe= 1.65
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.19 Sharpe= 0.71
# PnL avg=  0.27 PnL stddev=  0.45
# ShR avg=  1.18 ShR stddev=  0.47
#
# Top 10 results from ADF length 18.0 months checking on days 1-16
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.50 Sharpe= 1.42
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.33 Sharpe= 0.58
# PnL avg=  0.09 PnL stddev=  0.42
# ShR avg=  1.00 ShR stddev=  0.42
#
# Top 10 results from ADF length 18.0 months checking on days 1-11-21
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.42 Sharpe= 1.38
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.35 Sharpe= 0.56
# PnL avg=  0.03 PnL stddev=  0.39
# ShR avg=  0.97 ShR stddev=  0.41
#
# Top 10 results from ADF length 24.0 months checking on day 1
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.75 Sharpe= 1.70
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.28 Sharpe= 0.64
# PnL avg=  0.23 PnL stddev=  0.51
# ShR avg=  1.17 ShR stddev=  0.53
#
# Top 10 results from ADF length 24.0 months checking on days 1-16
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.57 Sharpe= 1.48
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.28 Sharpe= 0.63
# PnL avg=  0.14 PnL stddev=  0.43
# ShR avg=  1.05 ShR stddev=  0.42
#
# Top 10 results from ADF length 24.0 months checking on days 1-11-21
# ('JHSF3.SA', 'MRVE3.SA') PnL=  0.42 Sharpe= 1.37
# ('BBAS3.SA', 'ITUB4.SA') PnL= -0.36 Sharpe= 0.59
# PnL avg=  0.03 PnL stddev=  0.39
# ShR avg=  0.98 ShR stddev=  0.39

# %% [markdown]
# # Calculate Best PnL Option Statistics

# %%
opt = max_pnl_opt # if sortField == 'pnl' else max_sr_opt

(adfLen, adfDaysStr) = opt

adfDays = [int(d) for d in adfDaysStr.split('-')]

def calc_drawdown(cum_rets):
    cum_rets = cum_rets.apply(lambda x: 0 if abs(x) < 0.001 else x)
    # Calculate the running maximum
    running_max = cum_rets.cummax() # np.maximum.accumulate(cum_rets.dropna())
    # Calculate the percentage drawdown
    drawdown = (cum_rets)/running_max - 1

    return drawdown.replace(to_replace=-np.inf, method='ffill')

def calc_drawdown_df(cum_rets):

    cum_rets = cum_rets.apply(lambda x: 0 if abs(x) < 0.001 else x)
    # Calculate the running maximum
    running_max = cum_rets.cummax() # np.maximum.accumulate(cum_rets.dropna())

    dfd = pd.DataFrame( list(zip(cum_rets, running_max)), columns = ['rets', 'max'], index = cum_rets.index )

    # Calculate the percentage drawdown
    drawdown = dfd.apply(lambda x: 0.0 if x['max'] == 0 else x['rets']/x['max'] - 1, axis=1 ).apply(lambda x: 0 if abs(x) < 0.001 else x)

    return drawdown.replace(to_replace=-np.inf, method='ffill')

def plot_drawdown(drawdown, w=10, h=7):
    fig = plt.figure(figsize=(w, h))
    # Plot
    drawdown.plot(color='r')
    plt.ylabel('Returns')
    plt.fill_between(drawdown.index, drawdown, color='red')
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.2)
    plt.show()

print()
print(f'Recalculating returns for ADF with length {adfLen//21} months every month on day{"s" if len(adfDays)>1 else ""} {adfDays} from {endDate} to {end1}')

pnls = []
srs = []
bestPairsData = {}
bestPairsDrawdown = {}

cagrs = []
hit_ratios = []
avgP2Ls = []
retStds = []
maxDDs = []

portfolioAmtDic = {}

for pr in pairSpreadReturnsSorted[opt]:

    pair = pr[0]

    lookback = pairSpreadHalflife[pair]

    dfa = pairSpreadData[pair]
    dfa['dd'] = 0.0

    dfa = stat_arb(dfa, 'spread', lookback=lookback, std_dev=std_dev, start=endDate, end=None, adfDays=adfDays, adfLen=adfLen)

    df = dfa.loc[endDate:]
    #print(df.adf_score_cond.value_counts())

    if usePosAmt:
        pnl = (df['position_amt'].iloc[-1]-pairAmount)/pairAmount
        ret = df['mtm_amt']         # df['position_amt']
        sr = (np.mean(df['position_gain']))/np.std(df['position_gain'])*(252**0.5)
    elif useCumRet:
        pnl = df['cumret_spread'].iloc[-1]
        ret = df['cumret_spread']
        sr = (np.mean(df['ret_spread']))/np.std(df['ret_spread'])*(252**0.5)
    else:
        pnl = df['cumpnl_spread'].iloc[-1]
        ret = df['cumpnl_spread']
        sr = (np.mean(df['pnl_spread'])-(riskFreeYearRet/252))/np.std(df['pnl_spread'])*(252**0.5)

    #dd = calc_drawdown(ret)
    dd = calc_drawdown_df(ret)

    portfolioAmtDic[pair] = ret

    bestPairsDrawdown[pair] = dd

    dfa.loc[endDate:, 'dd'] = dd

    bestPairsData[pair] = df

    beta = pairSpreadBeta[pair]

    cagr  = (pnl + 1)**(252/len(df))-1

    num_wins = df['long_wins'].sum() + df['short_wins'].sum()
    num_loss = df['long_loss'].sum() + df['short_loss'].sum()

    hit_ratio = num_wins/num_loss if num_loss > 0 else np.inf

    avg_win  =  (df['win_rets']-1).sum()/num_wins if num_wins > 0 else 0.0
    avg_loss = -(df['loss_rets']-1).sum()/num_loss if num_loss > 0 else 0.0

    avgProfitToAvgLoss = avg_win/avg_loss if avg_loss != 0 else np.inf

    retStdDev = ret.std()

    print(pair, 'Cumulative pnl %7.2f%% The Sharpe Ratio %5.2f beta %5.2f max drawdown %5.2f%%' % (pnl*100, sr, beta, dd.min()*100))


    pnls.append(pnl)
    srs.append(sr)

    cagrs.append(cagr)
    hit_ratios.append(hit_ratio)
    avgP2Ls.append(avgProfitToAvgLoss)
    retStds.append(retStdDev)
    maxDDs.append(dd.min())


pnl_std = np.std(pnls)
pnl_avg = np.mean(pnls)

sr_std = np.std(srs)
sr_avg = np.mean(srs)

print(f'PnL avg={pnl_avg*100:6.2f}% PnL stddev={pnl_std*100:6.2f}%')
print(f'ShR avg={sr_avg:6.2f} ShR stddev={sr_std:6.2f}')
# Out:
# Recalculating returns for ADF with length 6 months every month on day [1] from 2020-05-01 to 2021-05-01
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl   54.55% The Sharpe Ratio  1.48 beta -0.19 max drawdown -27.74%
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl   44.76% The Sharpe Ratio  1.38 beta  0.09 max drawdown -38.32%
# PnL avg= 49.65% PnL stddev=  4.90%
# ShR avg=  1.43 ShR stddev=  0.05

# %%
cols = ['CAGR', 'Success Ratio of Trades', 'Average Profit to Average Loss', 'Standard Deviation of Returns', 'Maximum Draw-down']
cols = ['CAGR', 'Hit Ratio', 'Avg Profit/Loss', 'Rets StdDev', 'Max Draw-down']

dfs = pd.DataFrame(list(zip(cagrs, hit_ratios, avgP2Ls, retStds, maxDDs)),
                   columns = cols,
                   index = [ pr[0] for pr in pairSpreadReturnsSorted[opt]] ).sort_values('CAGR', ascending=False)

print(f"{'Pair':29}", '\t'.join([f'{c:9}' for c in cols]))
for index, row in dfs.reset_index().iterrows():
    print(str(row[0]), '\t'.join([f'{i:9.2f}' for i in list(row[1:-1])]), f'\t{list(row)[-1]*100:9.2f}%')
# Out:
# Pair                          CAGR     	Hit Ratio	Avg Profit/Loss	Rets StdDev	Max Draw-down
# ('JHSF3.SA', 'MRVE3.SA')      0.56	     4.33	     0.69	     0.19 	   -27.74%
# ('BBAS3.SA', 'ITUB4.SA')      0.46	     3.33	     0.75	     0.12 	   -38.32%

# %%
dfPort = pd.DataFrame(portfolioAmtDic)

numPairs = len(dfPort.columns)

initialAmount = pairAmount*numPairs

dfPort['portfolio'] = np.sum(dfPort, axis=1)
dfPort['portfolio_rets'] = dfPort['portfolio'].pct_change()

dd = calc_drawdown_df(dfPort['portfolio'])

pnl = (dfPort['portfolio'].iloc[-1]-initialAmount)/initialAmount

cagr  = (pnl + 1)**(252/len(df))-1

stdDev = dfPort['portfolio_rets'].std()

maxDD = dd.min()

print()
print(f'Porfolio rets: {pnl:.2f} CAGR: {cagr:.2f} StdDev: {stdDev:.2f} Max DrawDown: {maxDD:.2f}')
print()

dfPort['portfolio'].plot(figsize=(10, 5))
plt.show()

plot_drawdown(dd)
# Out:
# Porfolio rets: 0.50 CAGR: 0.51 StdDev: 0.02 Max DrawDown: -0.18

# %% [markdown]
# # Print Charts

# %%
w=10
h=5

for pair in bestPairsData:

    df = bestPairsData[pair]
    dd = bestPairsDrawdown[pair]

    s = np.mean(df['pnl_spread'])/np.std(df['pnl_spread'])*(252**0.5)
    print(pair, 'Cumulative pnl %7.2f The Sharpe Ratio %5.2f' % (df['cumpnl_spread'].iloc[-1], s))
    sr = (np.mean(df['ret_spread']))/np.std(df['ret_spread'])*(252**0.5)
    print(pair, 'Cumulative ret %7.2f The Sharpe Ratio %5.2f' % (df['cumret_spread'].iloc[-1], sr))


    # Plot the spread
    df[[pair[0], pair[1]]].plot(figsize=(w, h)) #, color=['lightskyblue', 'orange', 'green', 'red'])
    plt.ylabel("Spread")
    plt.show()

    print(pair, 'Cumulative pnl %7.2f The Sharpe Ratio %5.2f' % (df['cumpnl_spread'].iloc[-1], s))
    df[['cumpnl_spread', 'spread', 'moving_average', 'upper_band', 'lower_band', 'positions_prev']].plot(figsize=(w, h), color=['fuchsia', 'lightskyblue', 'orange', 'green', 'red', 'gray'], secondary_y='cumpnl_spread')
    plt.ylabel("cumpnl_spread")
    plt.show()

    print(pair, 'Cumulative ret %7.2f The Sharpe Ratio %5.2f' % (df['cumret_spread'].iloc[-1], sr))
    df[['cumret_spread', 'spread', 'moving_average', 'upper_band', 'lower_band', 'positions_prev']].plot(figsize=(w, h), color=['fuchsia', 'lightskyblue', 'orange', 'green', 'red', 'gray'], secondary_y='cumret_spread')
    plt.ylabel("cumret_spread")
    plt.show()

    print(pair, 'Cumulative ret %7.2f The Sharpe Ratio %5.2f' % (df['cumret_spread'].iloc[-1], sr))
    df[['position_amt', 'spread', 'trade_price', 'positions']].plot(figsize=(w, h), color=['fuchsia', 'lightskyblue', 'darkseagreen', 'gray'], secondary_y='position_amt')
    plt.show()

    print(pair, 'Cumulative ret %7.2f The Sharpe Ratio %5.2f' % (df['cumret_spread'].iloc[-1], sr))
    df[['mtm_amt', 'position_amt', 'spread', 'trade_price', 'positions']].plot(figsize=(w, h), color=['fuchsia', 'orange', 'lightskyblue', 'darkseagreen', 'gray'], secondary_y=['mtm_amt', 'position_amt'])
    plt.show()

    plot_drawdown(dd, w, h)
# Out:
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl    0.52 The Sharpe Ratio  1.19
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret    0.55 The Sharpe Ratio  1.87
# ('JHSF3.SA', 'MRVE3.SA') Cumulative pnl    0.52 The Sharpe Ratio  1.19
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret    0.55 The Sharpe Ratio  1.87
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret    0.55 The Sharpe Ratio  1.87
# ('JHSF3.SA', 'MRVE3.SA') Cumulative ret    0.55 The Sharpe Ratio  1.87
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl    0.65 The Sharpe Ratio  1.03
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret    0.45 The Sharpe Ratio  1.40
# ('BBAS3.SA', 'ITUB4.SA') Cumulative pnl    0.65 The Sharpe Ratio  1.03
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret    0.45 The Sharpe Ratio  1.40
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret    0.45 The Sharpe Ratio  1.40
# ('BBAS3.SA', 'ITUB4.SA') Cumulative ret    0.45 The Sharpe Ratio  1.40
